# %%
import numpy as np
import pandas as pd
import time
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import OneHotEncoder
# Out:
# D:\anaconda\setiing\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import matplotlib as plt
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']  #中文字符显示规范
import seaborn as sns
# %matplotlib inline
p = sns.color_palette()
sns.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

# %% [markdown]
# ## 用户信息

# %%
train = pd.read_csv("D:/rong360DC/creditData/feature/train_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/test_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
# test表中的用户标签为NAN,这里用-1来填充
test=test.fillna(-1)

# retset_index可以还原索引，重新变为默认的整型索引,添加了新的index行,若不添加则不会出现index索引
dataset=pd.concat([train, test], axis=0).reset_index()
# dataset.shape =(2000, 8)
label=dataset[['用户标识', '标签']]
dataset=dataset.drop(['index', '用户标识'], axis=1)
# (2000, 6)


dataset=pd.get_dummies(dataset,columns=['用户性别','用户职业','用户教育程度','用户婚姻状态','用户户口类型']).drop(['标签'],axis=1)
# 哑变量处理
# dataset.shape =(2000, 24)
# 特征工程扩展
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(interaction_only=True)
# interaction_only=True 表示变量自身和自身不会做运算
dataset=poly.fit_transform(dataset)
df = pd.DataFrame(dataset.reshape(2000,301))
df.interpolate(axis=1).values.reshape(dataset.shape)
# interpolate是作插值处理的意思

trains=pd.concat([label, df], axis=1)
# trains.shape (2000, 303)

# %% [markdown]
# # 用户浏览行为训练表

# %%
trains1 = trains
train = pd.read_csv("D:/rong360DC/creditData/feature/userbrowsetest_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/userbrowsetrain_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
dataset=pd.concat([train, test], axis=0)

temp = dataset[:]
temp.drop('放款时间', axis=1, inplace=True)
print(temp.shape)
dataset=dataset.fillna(-1)
temp['用户浏览行为缺失统计']=(dataset==-1).sum(axis=1)

# 用均值填充缺失值
temp.fillna(0, inplace=True)
print(temp.shape)

trains=pd.merge(trains, temp, how='left', on='用户标识')
print(trains.shape)
# Out:
# (2000, 39)
# (2000, 40)
# (2000, 342)
# D:\anaconda\setiing\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## 用户银行流水记录表

# %%
trains2 = trains
train = pd.read_csv("D:/rong360DC/creditData/feature/bankloantrain_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/bankloantest_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径

dataset = pd.concat([train, test], axis=0)
temp=dataset[:]

temp.drop('放款时间', axis=1, inplace=True)
print(temp.shape)

dataset=dataset.fillna(-1)
temp['用户银行流水记录缺失统计']=(dataset==-1).sum(axis=1)

temp.fillna(0, inplace=True)
print(temp.shape)
trains=pd.merge(trains, temp, how='left', on='用户标识')
print(trains.shape)
# Out:
# D:\anaconda\setiing\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# (2000, 25)
# (2000, 26)
# (2000, 367)

# %% [markdown]
# ## 用户账单表初级特征

# %%
trains3 = trains

train = pd.read_csv("D:/rong360DC/creditData/feature/chujiueserbilltrain_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/chujiueserbilltest_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径

dataset = pd.concat([train, test], axis=0)

temp=dataset[:]

temp.drop('放款时间', axis=1, inplace=True)

print(temp.shape)

# 统计行和列的缺失值数
dataset=dataset.fillna(-1)

temp['用户账单表初级特征缺失统计']=(dataset==-1).sum(axis=1)

# 特征轮：构造放款后和放款前差值特征
feature_name=temp.columns
for name in feature_name:
    if name.find("款后")>0:
        x1=name.replace('款后', '款前')
        if x1 in feature_name:
            temp[name + '与' + x1 + '差值'] = temp[name]-temp[x1]

temp.fillna(0, inplace=True)

print(temp.shape)

trains=pd.merge(trains, temp, how='left', on='用户标识')
print(trains.shape)
# Out:
# (2000, 56)
# D:\anaconda\setiing\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# (2000, 79)
# (2000, 445)

# %% [markdown]
# ## 用户账单表特征

# %%
trains4 = trains[:]

train = pd.read_csv("D:/rong360DC/creditData/feature/userbilltrainkonwtime_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/userbilltestkonwtime_20190303_A.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径

dataset = pd.concat([train, test], axis=0)
temp=dataset[:]
temp.drop("放款时间", axis=1, inplace=True)
print(temp.shape)

dataset=dataset.fillna(-1)

temp['用户账单表特征_时间已知缺失统计']=(dataset==-1).sum(axis=1)

feature_name = temp.columns

for name in feature_name:
    if name.find('款后') > 0:
        x1 = name.replace('款后', '款前')
        if x1 in feature_name:
            temp[name + '与' + x1 + '差值']=temp[name] - temp[x1]

# 填充缺失值
temp.fillna(0, inplace=True)
print(temp.shape)

trains=pd.merge(trains, temp, how='left', on='用户标识')

print(trains.shape)
# Out:
# D:\anaconda\setiing\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# (2000, 473)
# (2000, 706)
# (2000, 1150)

# %% [markdown]
# ## 用户账单表特征训练表

# %%
trains5 = trains[:]

train = pd.read_csv("D:/rong360DC/creditData/feature/userloantrain_20170203_unknow.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/userloantest_20170203_unknow.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径

print(train.shape)

# 在时间未知上期金额账单金额sum为空的地方的值为True
train已知=train[train['时间未知上期账单金额sum'].isnull().values==True]

print(train已知.shape)

# 在时间未知上期金额账单金额sum为空的地方的值为False
train未知=train[train['时间未知上期账单金额sum'].isnull().values==False]

print(train未知.shape)

# test_size:样本占比，如果是整数的话就是样本的数量，random_state:是随机数的种子
t1, t2=train_test_split(train未知, test_size=0.5, random_state=36)

print(t1.shape)

train = pd.concat([train已知, t1], axis=0)
print(train.shape)
# Out:
# (1000, 241)
# (488, 241)
# (512, 241)
# (256, 241)
# (744, 241)

# %%
dataset = pd.concat([train, test], axis=0)

temp=dataset[:]

print(temp.shape)

dataset=dataset.fillna(-1)

temp['用户账单表特征_时间未知缺失统计']=(dataset==-1).sum(axis=1)

temp.fillna(0, inplace=True)

print(temp.shape)


trains=pd.merge(trains, temp, how='inner', on='用户标识')
print(trains.shape)
# Out:
# (1744, 241)
# (1744, 242)
# (1744, 1391)

# %%
train未知.to_csv("D:/rong360DC/creditData/feature/billtimefeatureunknow_20190303.csv",index=None,encoding="gb2312")

# %% [markdown]
# ## 用户账单表特征训练表

# %%
trains6 = trains[:]


train = pd.read_csv("D:/rong360DC/creditData/feature/userloanfeaturetrain_20190303_all.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径
test = pd.read_csv("D:/rong360DC/creditData/feature/userloanfeaturetest_20190303_all.csv",encoding="gb2312", nrows=1000) # 注意自己数据路径

dataset = pd.concat([train, test], axis=0)

temp = dataset[:]

print(temp.shape)

dataset = dataset.fillna(-1)

temp['用户账单表特征_时间未知缺失统计']=(dataset==-1).sum(axis=1)

temp.fillna(0, inplace=True)

print(temp.shape)

trains=pd.merge(trains, temp, how='left', on='用户标识')
print(trains.shape)
# Out:
# (2000, 241)
# (2000, 242)
# (1744, 1632)

# %% [markdown]
# # 疑问：在变量中加入一个时间未知缺失统计的用处？？

# %%
trains.to_csv("D:/rong360DC/creditData/feature/featturesum_20190303_A.csv",index=None,encoding="gb2312")

dataset= pd.read_csv("D:/rong360DC/creditData/feature/featturesum_20190303_A.csv",encoding="gb2312") # 注意自己数据路径

beifen = 0
trains = 0

from sklearn.preprocessing import MinMaxScaler

names = dataset.columns.tolist()

print(len(names))

print(len(set(names)))

myset = set(names)

for item in myset:
    if names.count(item)>1:
        print(item)
        dataset=dataset.drop(item, axis=1)

print(dataset.shape)
# Out:
# 1632
# 1632
# (1744, 1632)

# %%
tests = dataset[(dataset['标签']<0)]

trains = dataset[(dataset['标签']>=0)]

#时间未知= pd.read_csv("D:/rong360DC/creditData/feature/billtimefeatureunknow_20190303.csv",encoding="gb2312", nrows=1000)[['用户标识','时间未知上期账单金额sum']]# 注意自己数据路径

#t1,t2=train_test_split(时间未知, test_size = 0.5,random_state=36)#

#trains=pd.merge(trains,t1,how='left', on = "用户标识")#


trains.shape
# Out:
# (744, 1632)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
import seaborn as sns
# %matplotlib inline
p = sns.color_palette()
sns.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

# %%
#t1=trains.columns
#t2=tests.columns
from sklearn import metrics
def ks(y_predicted, y_true):
    label=y_true
    #label = y_true.get_label()
    fpr,tpr,thres = metrics.roc_curve(label,y_predicted,pos_label=1)
    return 'ks',abs(fpr - tpr).max()

# %%
online_test=tests[:]
 
train,val = train_test_split(trains, test_size = 0.25,random_state=36)#41697/13886
offline_test=val[:]

print(tests.shape)
print(train.shape)
print(val.shape)
# Out:
# (1000, 1632)
# (558, 1632)
# (186, 1632)

# %%
start_time = time.time()
offline=0
online=0
params={'booster':'gbtree',
    'objective': 'rank:pairwise',
    'eval_metric':'auc',
    'gamma':0.1,
    'min_child_weight':1.1,
    'max_depth':7,
    'lambda':10,
    'subsample':0.7,
    'colsample_bytree':0.7,
    'colsample_bylevel':0.7,
    'eta': 0.01,
    'tree_method':'exact',
    'seed':1000,
    'nthread':12
    }

params1={
'booster':'gbtree',
'objective': 'binary:logistic',
'scale_pos_weight': 1/7.5,
#7183正样本
#55596条总样本
#差不多1:7.7这样子
'gamma':0.2,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
'max_depth':8, # 构建树的深度，越大越容易过拟合
'lambda':3,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
'subsample':0.7, # 随机采样训练样本
#'colsample_bytree':0.7, # 生成树时进行的列采样
'min_child_weight':3, 
# 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
#，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
#这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
'eta': 0.03, # 如同学习率
'seed':1000,
'nthread':12,# cpu 线程数
'eval_metric': 'auc'
}

plst = list(params.items())
num_rounds = 5000 # 迭代次数

y = train.标签
X = train.drop(['标签','用户标识'],axis=1)
#X=train[feature_list]

val_y = val.标签
val_X = val.drop(['标签','用户标识'],axis=1)
#val_X = val[feature_list]

offline_test_X=offline_test.drop(['标签','用户标识'],axis=1)
online_test_X=online_test.drop(['标签','用户标识'],axis=1)
#offline_test_X=offline_test[feature_list]
#online_test_X=online_test[feature_list]

xgb_train = xgb.DMatrix(X, label=y)
xgb_val = xgb.DMatrix(val_X,label=val_y)

xgb_offline_test = xgb.DMatrix(offline_test_X)
xgb_online_test = xgb.DMatrix(online_test_X)

# return 训练和验证的错误率
watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]

print ("跑到这里了xgb.train")

# training model 
# early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
model = xgb.train(plst, xgb_train,num_boost_round=7000,evals=watchlist,early_stopping_rounds=500)
print ("跑到这里了save_model")


model.save_model('D:/rong360DC/creditData/model20190310_unkowndata.model') # 用于存储训练出的模型

print ("best best_ntree_limit",model.best_ntree_limit)   #did not save the best,why?
print ("best best_iteration",model.best_iteration) #get it?

print ("跑到这里了model.predict")
# Out:
# 跑到这里了xgb.train
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [0]	train-auc:0.852954	val-auc:0.715949
# Multiple eval metrics have been passed: 'val-auc' will be used for early stopping.
#
# Will train until val-auc hasn't improved in 500 rounds.
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [1]	train-auc:0.911889	val-auc:0.729641
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=7
# [2]	train-auc:0.913207	val-auc:0.714972
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [3]	train-auc:0.915197	val-auc:0.712927
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [4]	train-auc:0.927285	val-auc:0.708481
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [5]	train-auc:0.935667	val-auc:0.710082
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [6]	train-auc:0.943527	val-auc:0.715683
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [7]	train-auc:0.944024	val-auc:0.715416
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [8]	train-auc:0.943278	val-auc:0.706348
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [9]	train-auc:0.94339	val-auc:0.707237
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [10]	train-auc:0.944149	val-auc:0.70857
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [11]	train-auc:0.947979	val-auc:0.712571
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [12]	train-auc:0.951946	val-auc:0.712927
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [13]	train-auc:0.951324	val-auc:0.718083
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [14]	train-auc:0.955254	val-auc:0.713371
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [15]	train-auc:0.955802	val-auc:0.716216
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [16]	train-auc:0.95814	val-auc:0.718883
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [17]	train-auc:0.957269	val-auc:0.717639
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=7
# [18]	train-auc:0.956075	val-auc:0.716038
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [19]	train-auc:0.957194	val-auc:0.716216
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [20]	train-auc:0.960851	val-auc:0.715149
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=7
# [21]	train-auc:0.960577	val-auc:0.721906
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=7
# [22]	train-auc:0.958438	val-auc:0.720306
# [08:49:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [23]	train-auc:0.958935	val-auc:0.718528
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [24]	train-auc:0.957965	val-auc:0.721195
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [25]	train-auc:0.957866	val-auc:0.719239
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [26]	train-auc:0.957518	val-auc:0.719595
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [27]	train-auc:0.956871	val-auc:0.716216
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [28]	train-auc:0.957269	val-auc:0.716927
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [29]	train-auc:0.957418	val-auc:0.716927
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [30]	train-auc:0.95804	val-auc:0.71675
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [31]	train-auc:0.959408	val-auc:0.715505
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [32]	train-auc:0.958911	val-auc:0.717816
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [33]	train-auc:0.961448	val-auc:0.717283
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [34]	train-auc:0.963736	val-auc:0.716394
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=7
# [35]	train-auc:0.963661	val-auc:0.719239
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [36]	train-auc:0.96197	val-auc:0.716927
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [37]	train-auc:0.961746	val-auc:0.715861
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [38]	train-auc:0.963089	val-auc:0.716038
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [39]	train-auc:0.964059	val-auc:0.716927
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [40]	train-auc:0.963313	val-auc:0.713193
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [41]	train-auc:0.965203	val-auc:0.712838
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [42]	train-auc:0.966024	val-auc:0.713193
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [43]	train-auc:0.967318	val-auc:0.714616
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [44]	train-auc:0.967541	val-auc:0.712127
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [45]	train-auc:0.967417	val-auc:0.713016
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [46]	train-auc:0.966895	val-auc:0.714616
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [47]	train-auc:0.966074	val-auc:0.714794
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [48]	train-auc:0.965875	val-auc:0.717639
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=7
# [49]	train-auc:0.965278	val-auc:0.717105
# [08:49:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [50]	train-auc:0.965775	val-auc:0.716927
# [08:49:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [51]	train-auc:0.966422	val-auc:0.715861
# [08:49:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [52]	train-auc:0.967218	val-auc:0.716394
# [08:49:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [53]	train-auc:0.96692	val-auc:0.716038
# [08:49:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [54]	train-auc:0.967442	val-auc:0.716216
# [08:49:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
#
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [180]	train-auc:0.981719	val-auc:0.718528
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [181]	train-auc:0.981644	val-auc:0.719061
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 4 pruned nodes, max_depth=7
# [182]	train-auc:0.982142	val-auc:0.718706
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [183]	train-auc:0.982017	val-auc:0.71835
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [184]	train-auc:0.982241	val-auc:0.718528
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=7
# [185]	train-auc:0.982738	val-auc:0.718883
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [186]	train-auc:0.982813	val-auc:0.718706
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=7
# [187]	train-auc:0.983037	val-auc:0.718528
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [188]	train-auc:0.983136	val-auc:0.718528
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=7
# [189]	train-auc:0.983186	val-auc:0.718172
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=7
# [190]	train-auc:0.983112	val-auc:0.71835
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [191]	train-auc:0.983261	val-auc:0.718706
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [192]	train-auc:0.983286	val-auc:0.718706
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [193]	train-auc:0.983236	val-auc:0.718706
# [08:49:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [194]	train-auc:0.983037	val-auc:0.717816
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [195]	train-auc:0.983236	val-auc:0.718706
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [196]	train-auc:0.983385	val-auc:0.717461
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [197]	train-auc:0.983634	val-auc:0.71835
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=7
# [198]	train-auc:0.983858	val-auc:0.718172
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [199]	train-auc:0.983833	val-auc:0.71835
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=7
# [200]	train-auc:0.984007	val-auc:0.718172
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [201]	train-auc:0.983982	val-auc:0.718706
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [202]	train-auc:0.984206	val-auc:0.717816
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [203]	train-auc:0.984256	val-auc:0.717816
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=7
# [204]	train-auc:0.98443	val-auc:0.716572
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [205]	train-auc:0.984554	val-auc:0.71675
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [206]	train-auc:0.984703	val-auc:0.718706
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [207]	train-auc:0.984803	val-auc:0.718706
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=7
# [208]	train-auc:0.984927	val-auc:0.718172
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [209]	train-auc:0.985201	val-auc:0.719061
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [210]	train-auc:0.985325	val-auc:0.718883
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [211]	train-auc:0.985176	val-auc:0.71835
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [212]	train-auc:0.9853	val-auc:0.718172
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=7
# [213]	train-auc:0.985275	val-auc:0.717816
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=7
# [214]	train-auc:0.9853	val-auc:0.717639
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [215]	train-auc:0.985126	val-auc:0.718528
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [216]	train-auc:0.985375	val-auc:0.717283
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [217]	train-auc:0.985524	val-auc:0.717105
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [218]	train-auc:0.985524	val-auc:0.717283
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=7
# [219]	train-auc:0.985848	val-auc:0.718172
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=7
# [220]	train-auc:0.985947	val-auc:0.718883
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=7
# [221]	train-auc:0.986046	val-auc:0.719061
# [08:49:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=7
# [222]	train-auc:0.986345	val-auc:0.71995
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [223]	train-auc:0.986444	val-auc:0.719772
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [224]	train-auc:0.986569	val-auc:0.718528
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=7
# [225]	train-auc:0.986619	val-auc:0.718883
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [226]	train-auc:0.986768	val-auc:0.71835
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [227]	train-auc:0.986892	val-auc:0.718528
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [228]	train-auc:0.987017	val-auc:0.71835
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [229]	train-auc:0.987265	val-auc:0.718528
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=7
# [230]	train-auc:0.98729	val-auc:0.717639
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=7
# [231]	train-auc:0.987414	val-auc:0.718172
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [232]	train-auc:0.987315	val-auc:0.717639
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=7
# [233]	train-auc:0.987613	val-auc:0.717816
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [234]	train-auc:0.987564	val-auc:0.717105
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [235]	train-auc:0.987663	val-auc:0.717105
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=7
# [236]	train-auc:0.987763	val-auc:0.716927
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [237]	train-auc:0.988011	val-auc:0.717105
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [238]	train-auc:0.988061	val-auc:0.71675
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [239]	train-auc:0.988011	val-auc:0.717283
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=7
# [240]	train-auc:0.98826	val-auc:0.71675
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=7
# [241]	train-auc:0.98826	val-auc:0.718528
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=7
# [242]	train-auc:0.988335	val-auc:0.717816
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [243]	train-auc:0.98826	val-auc:0.717639
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [244]	train-auc:0.98836	val-auc:0.718172
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [245]	train-auc:0.98831	val-auc:0.717461
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=7
# [246]	train-auc:0.988434	val-auc:0.718172
# [08:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=7
# [247]	train-auc:0.988459	val-auc:0.717816
# ...
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=7
# [420]	train-auc:0.996369	val-auc:0.714438
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [421]	train-auc:0.996418	val-auc:0.71426
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [422]	train-auc:0.996418	val-auc:0.71426
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=7
# [423]	train-auc:0.996468	val-auc:0.713905
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=7
# [424]	train-auc:0.996443	val-auc:0.71426
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=7
# [425]	train-auc:0.996468	val-auc:0.714082
# [08:49:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=7
# [426]	train-auc:0.996543	val-auc:0.713905
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=7
# [427]	train-auc:0.996543	val-auc:0.714082
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=7
# [428]	train-auc:0.996592	val-auc:0.713905
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [429]	train-auc:0.996543	val-auc:0.714438
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=7
# [430]	train-auc:0.996543	val-auc:0.713905
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [431]	train-auc:0.996642	val-auc:0.714082
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=7
# [432]	train-auc:0.996667	val-auc:0.714082
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=7
# [433]	train-auc:0.996617	val-auc:0.714082
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=7
# [434]	train-auc:0.996617	val-auc:0.714082
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=7
# [435]	train-auc:0.996692	val-auc:0.713727
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=7
# [436]	train-auc:0.996667	val-auc:0.713727
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [437]	train-auc:0.996667	val-auc:0.713905
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=7
# [438]	train-auc:0.996692	val-auc:0.713371
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [439]	train-auc:0.996717	val-auc:0.713905
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [440]	train-auc:0.996816	val-auc:0.713727
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [441]	train-auc:0.996841	val-auc:0.713727
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=7
# [442]	train-auc:0.996791	val-auc:0.713905
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=7
# [443]	train-auc:0.996791	val-auc:0.714438
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [444]	train-auc:0.996891	val-auc:0.71426
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=7
# [445]	train-auc:0.996916	val-auc:0.714082
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [446]	train-auc:0.996891	val-auc:0.71426
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 8 pruned nodes, max_depth=7
# [447]	train-auc:0.996841	val-auc:0.714438
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [448]	train-auc:0.996866	val-auc:0.714438
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=7
# [449]	train-auc:0.996916	val-auc:0.71426
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [450]	train-auc:0.996916	val-auc:0.714438
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=7
# [451]	train-auc:0.996866	val-auc:0.71426
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=7
# [452]	train-auc:0.996941	val-auc:0.714972
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=7
# [453]	train-auc:0.996941	val-auc:0.714794
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=7
# [454]	train-auc:0.996916	val-auc:0.714972
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=7
# [455]	train-auc:0.996941	val-auc:0.715149
# [08:49:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [456]	train-auc:0.996966	val-auc:0.714972
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=7
# [457]	train-auc:0.99709	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=7
# [458]	train-auc:0.99714	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [459]	train-auc:0.997115	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=7
# [460]	train-auc:0.99709	val-auc:0.715149
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=7
# [461]	train-auc:0.997115	val-auc:0.715683
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [462]	train-auc:0.99709	val-auc:0.715683
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [463]	train-auc:0.99709	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [464]	train-auc:0.99714	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 12 pruned nodes, max_depth=7
# [465]	train-auc:0.997239	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 10 pruned nodes, max_depth=7
# [466]	train-auc:0.997264	val-auc:0.715327
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [467]	train-auc:0.997289	val-auc:0.715149
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=7
# [468]	train-auc:0.997289	val-auc:0.715505
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=7
# [469]	train-auc:0.997289	val-auc:0.715861
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [470]	train-auc:0.997239	val-auc:0.715505
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=7
# [471]	train-auc:0.997214	val-auc:0.715683
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=7
# [472]	train-auc:0.997264	val-auc:0.715861
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [473]	train-auc:0.997289	val-auc:0.716038
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=7
# [474]	train-auc:0.997339	val-auc:0.716216
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=7
# [475]	train-auc:0.997364	val-auc:0.716394
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=7
# [476]	train-auc:0.997339	val-auc:0.716038
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=7
# [477]	train-auc:0.997388	val-auc:0.716038
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [478]	train-auc:0.997388	val-auc:0.716038
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [479]	train-auc:0.997388	val-auc:0.716216
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=7
# [480]	train-auc:0.997413	val-auc:0.71675
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=7
# [481]	train-auc:0.997413	val-auc:0.716216
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=7
# [482]	train-auc:0.997413	val-auc:0.715505
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=7
# [483]	train-auc:0.997438	val-auc:0.715149
# [08:49:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=7
# [484]	train-auc:0.997438	val-auc:0.715683
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [485]	train-auc:0.997438	val-auc:0.715861
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=7
# [486]	train-auc:0.997438	val-auc:0.715683
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [487]	train-auc:0.997438	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=7
# [488]	train-auc:0.997438	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=7
# [489]	train-auc:0.997413	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=7
# [490]	train-auc:0.997438	val-auc:0.715327
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=7
# [491]	train-auc:0.997463	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=7
# [492]	train-auc:0.997513	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=7
# [493]	train-auc:0.997513	val-auc:0.715683
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [494]	train-auc:0.997513	val-auc:0.715149
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=7
# [495]	train-auc:0.997538	val-auc:0.715683
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=7
# [496]	train-auc:0.997513	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=7
# [497]	train-auc:0.997513	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=7
# [498]	train-auc:0.997513	val-auc:0.715683
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=7
# [499]	train-auc:0.997562	val-auc:0.715327
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=7
# [500]	train-auc:0.997587	val-auc:0.715505
# [08:49:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=7
# [501]	train-auc:0.997562	val-auc:0.714794
# Stopping. Best iteration:
# [1]	train-auc:0.911889	val-auc:0.729641
#
# 跑到这里了save_model
# best best_ntree_limit 2
# best best_iteration 1
# 跑到这里了model.predict

# %%
preds_offline = model.predict(xgb_offline_test,ntree_limit=model.best_iteration)#

preds_online = model.predict(xgb_online_test,ntree_limit=model.best_iteration)#

offline=offline_test[['用户标识','标签']]
online=online_test[['用户标识']]

offline['预测']=preds_offline
online['预测']=preds_online
# Out:
# D:\anaconda\setiing\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\anaconda\setiing\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
print("线下得分;")
print(ks(offline.预测,offline.标签))

print ("跑到这里了,输出结果")
# Out:
# 线下得分;
# ('ks', 0.371977240398293)
# 跑到这里了,输出结果

# %%
a = np.array(online.预测)

# %%
from sklearn.preprocessing import MinMaxScaler
online.预测 = MinMaxScaler().fit_transform(np.array(online.预测).reshape(-1, 1))
output=online[['用户标识','预测']].rename(index=str, columns={"用户标识": "userid", "预测": "probability"})
output.to_csv("D:/rong360DC/creditData/model/20170204_D_最好成绩特征训练集删去部分时间未知样本.csv",index=None,encoding='utf-8')
# Out:
# D:\anaconda\setiing\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#save feature score and feature information:  feature,score,min,max,n_null,n_gt1w
feature_score = model.get_fscore()
feature_score = sorted(feature_score.items(), key=lambda x:x[1],reverse=True)
fs = []
for (key,value) in feature_score:
    fs.append("{0},{1}\n".format(key,value))
    
with open('D:/rong360DC/creditData/20170204_D_最好成绩特征训练集删去部分时间未知样本.csv','w') as f:
        f.writelines("feature,score\n")
        f.writelines(fs)
        
cost_time = time.time()-start_time
print ("",'\n',"cost time:",cost_time,"(s)")
print ("跑到这里了,结束！")
# Out:
#
#  cost time: 18.655977487564087 (s)
# 跑到这里了,结束！
